# %%
import numpy as np
from numpy import array, concatenate, zeros, ones, shape, reshape, arange, linspace, pi, mean, std
from time import time

import random
from math import log, ceil

import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
matplotlib.rcParams['font.family']='serif'
matplotlib.rc('text', usetex=True)
matplotlib.rcParams['axes.unicode_minus']=False
matplotlib.rcParams.update({'font.size': 18})

# %%
thr_1 = 1e-8
thr_2 = 1e-1
path = "/home/investigator/Work/qaoa-qfi/Results/"

p_c_star_bins_thr_1, counts_s_cut_thr_1, counts_rel_cut_thr_1 = np.load(path + f"cut-bins-counts_s_r-thr={thr_1}.npy")
p_c_star_bins_thr_1, counts_s_sat_thr_1, counts_rel_sat_thr_1 = np.load(path + f"sat-bins-counts_s_r-thr={thr_1}.npy")

p_c_star_bins_thr_2, counts_s_cut_thr_2, counts_rel_cut_thr_2 = np.load(path + f"cut-bins-counts_s_r-thr={thr_2}.npy")
p_c_star_bins_thr_2, counts_s_sat_thr_2, counts_rel_sat_thr_2 = np.load(path + f"sat-bins-counts_s_r-thr={thr_2}.npy")

# %%
plt.figure(figsize=(6.25, 4))
plt.axvline(1, color="green")
plt.axhline(0, color="black")
plt.axhline(100, color="black")
plt.scatter([0], [0], color="White", marker="^", s=0, zorder=10, label=f"MAX-CUT")
plt.plot(p_c_star_bins_thr_1, counts_s_cut_thr_1, linewidth=5, color="blue", zorder=10, label="$\epsilon=10^{" + str(int(np.log10(thr_1))) + "}$")
plt.plot(p_c_star_bins_thr_2, counts_s_cut_thr_2, linewidth=3, linestyle="--", zorder=9, color="blue", label="$\epsilon=10^{" + str(int(np.log10(thr_2))) + "}$")
plt.scatter([0], [0], color="White", marker="s", s=0, zorder=10, label=f"MAX-2-SAT")
plt.plot(p_c_star_bins_thr_1, counts_s_sat_thr_1, linewidth=5, color="red", zorder=10, label="$\epsilon=10^{" + str(int(np.log10(thr_1))) + "}$")
plt.plot(p_c_star_bins_thr_2, counts_s_sat_thr_2, linewidth=3, linestyle="--", zorder=9, color="red", label="$\epsilon=10^{" + str(int(np.log10(thr_2))) + "}$")
plt.xlabel("$p/p_c$")
plt.ylabel("Converged instances, \%")
plt.grid()
plt.legend(framealpha=1, loc=4)
plt.tight_layout()
plt.savefig(path + "convergence_counts-inst-thr.pdf", transparent=True, bbox_inches='tight')
plt.show()

plt.figure(figsize=(6.25, 4))
plt.axvline(1, color="green")
plt.axhline(0, color="black")
plt.axhline(100, color="black")
plt.scatter([0], [0], color="White", marker="^", s=0, zorder=10, label=f"MAX-CUT")
plt.plot(p_c_star_bins_thr_1, counts_rel_cut_thr_1, linewidth=5, color="blue", zorder=10, label="$\epsilon=10^{" + str(int(np.log10(thr_1))) + "}$")
plt.plot(p_c_star_bins_thr_2, counts_rel_cut_thr_2, linewidth=3, linestyle="--", zorder=9, color="blue", label="$\epsilon=10^{" + str(int(np.log10(thr_2))) + "}$")
plt.scatter([0], [0], color="White", marker="s", s=0, zorder=10, label=f"MAX-2-SAT")
plt.plot(p_c_star_bins_thr_1, counts_rel_sat_thr_1, linewidth=5, color="red", zorder=10, label="$\epsilon=10^{" + str(int(np.log10(thr_1))) + "}$")
plt.plot(p_c_star_bins_thr_2, counts_rel_sat_thr_2, linewidth=3, linestyle="--", zorder=9, color="red", label="$\epsilon=10^{" + str(int(np.log10(thr_2))) + "}$")
plt.xlabel("$p/p_c$")
plt.ylabel("Converged runs, \%")
plt.grid()
plt.legend(framealpha=1, loc=4)
plt.tight_layout()
plt.savefig(path + "convergence_counts-seed-thr.pdf", transparent=True, bbox_inches='tight')
plt.show()

# %% [markdown]
# # old

# %%
path = "/home/investigator/Work/qaoa-qfi/Results/"

p_c_star_bins, counts_s_cut, counts_rel_cut = np.load(path + "cut-bins-counts_s_r.npy")
p_c_star_bins, counts_s_sat, counts_rel_sat = np.load(path + "sat-bins-counts_s_r.npy")

# %%
plt.figure(figsize=(6.25, 4))
plt.axvline(1, color="green")
plt.axhline(0, color="black")
plt.axhline(100, color="black")
plt.plot(p_c_star_bins, counts_s_cut, linewidth=5, color="blue", label="MAX-CUT", zorder=10)
plt.plot(p_c_star_bins, counts_s_sat, linewidth=5, color="red", label="MAX-2-SAT", zorder=9)
plt.xlabel("$p/p_c$")
plt.ylabel("Converged instances, \%")
plt.grid()
plt.legend(framealpha=1, loc=5)
plt.tight_layout()

# plt.savefig("convergence_counts-inst.pdf", transparent=True, bbox_inches='tight')
plt.show()
plt.figure(figsize=(6.25, 4))
plt.axvline(1, color="green")
plt.axhline(0, color="black")
plt.axhline(100, color="black")
plt.plot(p_c_star_bins, counts_rel_cut, linewidth=5, color="blue", label="MAX-CUT", zorder=10)
plt.plot(p_c_star_bins, counts_rel_sat, linewidth=5, color="red", label="MAX-2-SAT", zorder=9)
plt.xlabel("$p/p_c$")
plt.ylabel("Converged runs, \%")
plt.grid()
plt.legend(framealpha=1, loc=5)
plt.tight_layout()
# plt.savefig("convergence_counts-seed-rel.pdf", transparent=True, bbox_inches='tight')
plt.show()

# %%
thrs = [1e-1, 1e-2, 1e-5, 1e-8]
path = "/home/investigator/Work/qaoa-qfi/Results/"
colors_1 = ["red", "orange", "maroon", "salmon"]
colors_2 =["blue", "tab:blue", "navy", "cyan"]


for i in range(len(thrs)):
    p_c_star_bins_thr, counts_s_cut_thr, counts_rel_cut_thr = np.load(path + f"cut-bins-counts_s_r-thr={thrs[i]}.npy")
    p_c_star_bins_thr, counts_s_sat_thr, counts_rel_sat_thr = np.load(path + f"sat-bins-counts_s_r-thr={thrs[i]}.npy")
    plt.figure(figsize=(6.25, 4))
    plt.axvline(1, color="green")
    plt.axhline(0, color="black")
    plt.axhline(100, color="black")
    plt.plot(p_c_star_bins, counts_s_cut, linewidth=5, color="blue", label="MAX-CUT", zorder=10)
    plt.plot(p_c_star_bins, counts_s_sat, linewidth=5, color="red", label="MAX-2-SAT", zorder=9)
    plt.plot(p_c_star_bins_thr, counts_s_cut_thr, linewidth=3, linestyle="--", zorder=10, color="blue")
    plt.plot(p_c_star_bins_thr, counts_s_sat_thr, linewidth=3, linestyle="--", zorder=9, color="red")
    plt.xlabel("$p/p_c$")
    plt.ylabel("Converged instances, %")
    plt.title(f"threshold: {thrs[i]}")
    plt.grid()
    plt.legend(framealpha=1, loc=5)
    plt.tight_layout()
    # plt.savefig("convergence_counts-inst.pdf", transparent=True, bbox_inches='tight')
    plt.show()

print("\n\n\n")

for i in range(len(thrs)):
    p_c_star_bins_thr, counts_s_cut_thr, counts_rel_cut_thr = np.load(path + f"cut-bins-counts_s_r-thr={thrs[i]}.npy")
    p_c_star_bins_thr, counts_s_sat_thr, counts_rel_sat_thr = np.load(path + f"sat-bins-counts_s_r-thr={thrs[i]}.npy")
    plt.figure(figsize=(6.25, 4))
    plt.axvline(1, color="green")
    plt.axhline(0, color="black")
    plt.axhline(100, color="black")
    plt.plot(p_c_star_bins, counts_rel_cut, linewidth=5, color="blue", label="MAX-CUT", zorder=10)
    plt.plot(p_c_star_bins, counts_rel_sat, linewidth=5, color="red", label="MAX-2-SAT", zorder=9)
    plt.plot(p_c_star_bins_thr, counts_rel_cut_thr, linewidth=3, linestyle="--", zorder=10, color="blue")
    plt.plot(p_c_star_bins_thr, counts_rel_sat_thr, linewidth=3, linestyle="--", zorder=9, color="red")
    plt.xlabel("$p/p_c$")
    plt.ylabel("Converged runs, %")
    plt.title(f"threshold: {thrs[i]}")
    plt.grid()
    plt.legend(framealpha=1, loc=5)
    plt.tight_layout()
    # plt.savefig("convergence_counts-inst.pdf", transparent=True, bbox_inches='tight')
    plt.show()

# %%
path = "/home/investigator/Work/qaoa-qfi/Results/"
p_c_star_bins_thr, counts_s_cut_thr, counts_rel_cut_thr = np.load(path + "cut-bins-counts_s_r-thr.npy")
p_c_star_bins_thr, counts_s_sat_thr, counts_rel_sat_thr = np.load(path + "sat-bins-counts_s_r-thr.npy")

plt.figure(figsize=(6.25, 4))
plt.axvline(1, color="green")
plt.axhline(0, color="black")
plt.axhline(100, color="black")
plt.plot(p_c_star_bins, counts_s_cut, linewidth=5, color="blue", label="MAX-CUT", zorder=10)
plt.plot(p_c_star_bins, counts_s_sat, linewidth=5, color="red", label="MAX-2-SAT", zorder=9)
plt.plot(p_c_star_bins_thr, counts_s_cut_thr, linewidth=3, color="blue", linestyle="--", zorder=10)
plt.plot(p_c_star_bins_thr, counts_s_sat_thr, linewidth=3, color="red", linestyle="--", zorder=9)
plt.xlabel("$p/p_c$")
plt.ylabel("Converged instances, \%")
plt.grid()
plt.legend(framealpha=1, loc=5)
plt.tight_layout()
# plt.savefig("convergence_counts-inst.pdf", transparent=True, bbox_inches='tight')
plt.show()

plt.figure(figsize=(6.25, 4))
plt.axvline(1, color="green")
plt.axhline(0, color="black")
plt.axhline(100, color="black")
plt.plot(p_c_star_bins, counts_rel_cut, linewidth=5, color="blue", label="MAX-CUT", zorder=10)
plt.plot(p_c_star_bins, counts_rel_sat, linewidth=5, color="red", label="MAX-2-SAT", zorder=9)
plt.plot(p_c_star_bins_thr, counts_rel_cut_thr, linewidth=3, color="blue", linestyle="--", zorder=10)
plt.plot(p_c_star_bins_thr, counts_rel_sat_thr, linewidth=3, color="red", linestyle="--", zorder=9)
plt.xlabel("$p/p_c$")
plt.ylabel("Converged runs, \%")
plt.grid()
plt.legend(framealpha=1, loc=5)
plt.tight_layout()
# plt.savefig("convergence_counts-seed-rel.pdf", transparent=True, bbox_inches='tight')
plt.show()
